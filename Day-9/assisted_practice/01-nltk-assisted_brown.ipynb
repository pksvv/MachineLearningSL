# %% [markdown]
# # About the dataset - Brown Corpus (American English)
#
# https://en.wikipedia.org/wiki/Brown_Corpus
#
# #### Brown Corpus was compiled in the 1960s by Henry Kučera and W. Nelson Francis at Brown University, Providence, Rhode Island as a general corpus (text collection) in the field of corpus linguistics.
#
#
# #### It contains 500 samples of English-language text, totaling roughly one million words, compiled from works published in the United States in 1961.

# %% [markdown]
# ## Compare Text Analytics, NLP and Text Mining
#
#
# Text mining also referred to as text analytics.
#
#
# Text mining is a process of exploring sizeable textual data and find patterns.
#
#
# Text Mining process the text itself, while NLP process with the underlying metadata.
#
#
# Finding frequency counts of words, length of the sentence, presence/absence of specific words is known as text mining.
#
#
# Natural language processing is one of the components of text mining. NLP helps identified sentiment, finding entities in the sentence, and category of blog/article.
#
#
# Text mining is preprocessed data for text analytics. In Text Analytics, statistical and machine learning algorithm used to classify information.

# %% [markdown]
# ## NLTK - Natural Language Toolkit
#
# NLTK is a powerful Python package that provides a set of diverse natural languages algorithms.
#
#
# It is free, opensource, easy to use, large community, and well documented.
#
#
# NLTK consists of the most common algorithms such as tokenizing, part-of-speech tagging, stemming, sentiment analysis, topic segmentation, and named entity recognition.
#
#
# NLTK helps the computer to analysis, preprocess, and understand the written text.

# %%
import nltk

# %%
with open('../datasets/brown_corpus_ca10.txt', 'r') as myfile:
    data=myfile.read().replace('\n', '')

# %%
data2 = data.replace("/","")

# %% [markdown]
# Tokenization
# ====
#
#
# Tokenization is the first step in text analytics.
#
#
# The process of breaking down a text paragraph into smaller chunks such as words or sentence is called Tokenization.
#
#
# Token is a single entity that is building blocks for sentence or paragraph.
#
#
# **Sentence tokenization** is the process of  *splitting up strings into “sentences”*
#
# **Word tokenization** is the process of  *splitting up “sentences” into “words”*

# %%
# Each line is one advertisement.
for i, line in enumerate(data2.split('\n')):
    if i > 10: # Lets take a look at the first 10 ads.
        break
    print(str(i) + ':\t' + line)
# Out:
# 0:		Vincentnp G.np Ierullinp hashvz beenben appointedvbn temporaryjj assistantnn districtnn attorneynn ,, itpps wasbedz announcedvbn Mondaynr byin Charlesnp E.np Raymondnp ,, Districtnn-tl Attorneynn-tl ..	Ierullinp willmd replacevb Desmondnp D.np Connallnp whowps hashvz beenben calledvbn toin activejj militaryjj servicenn butcc isbez expectedvbn backrb onin theat jobnn byin Marchnp 31cd ..	Ierullinp ,, 29cd ,, hashvz beenben practicingvbg inin Portlandnp sincein Novembernp ,, 1959cd ..Hepps isbez aat graduatenn ofin Portlandnp-tl Universitynn-tl andcc theat Northwesternjj-tl Collegenn-tl ofin-tl Lawnn-tl ..Hepps isbez marriedvbn andcc theat fathernn ofin threecd childrennns ..	Helpingvbg foreignjj countriesnns toto buildvb aat soundjj politicaljj structurenn isbez moreql importantjj thancs aidingvbg themppo economicallyrb ,, E.np M.np Martinnp ,, assistantnn secretarynn ofin statenn forin economicjj affairsnns toldvbd membersnns ofin theat Worldnn-tl Affairsnns-tl Councilnn-tl Monda
# ...

# %% [markdown]
# # Sentence Tokenization

# %%
from nltk import sent_tokenize, word_tokenize

# %%
sent_tokenize(data2)
# Out:
# ["\tVincentnp G.np Ierullinp hashvz beenben appointedvbn temporaryjj assistantnn districtnn attorneynn ,, itpps wasbedz announcedvbn Mondaynr byin Charlesnp E.np Raymondnp ,, Districtnn-tl Attorneynn-tl ..\tIerullinp willmd replacevb Desmondnp D.np Connallnp whowps hashvz beenben calledvbn toin activejj militaryjj servicenn butcc isbez expectedvbn backrb onin theat jobnn byin Marchnp 31cd ..\tIerullinp ,, 29cd ,, hashvz beenben practicingvbg inin Portlandnp sincein Novembernp ,, 1959cd ..Hepps isbez aat graduatenn ofin Portlandnp-tl Universitynn-tl andcc theat Northwesternjj-tl Collegenn-tl ofin-tl Lawnn-tl ..Hepps isbez marriedvbn andcc theat fathernn ofin threecd childrennns ..\tHelpingvbg foreignjj countriesnns toto buildvb aat soundjj politicaljj structurenn isbez moreql importantjj thancs aidingvbg themppo economicallyrb ,, E.np M.np Martinnp ,, assistantnn secretarynn ofin statenn forin economicjj affairsnns toldvbd membersnns ofin theat Worldnn-tl Affairsnns-tl Councilnn-tl Mo
# ...

# %%
for sent in sent_tokenize(data2):
    print(word_tokenize(sent))
# Out:
# ['Vincentnp', 'G.np', 'Ierullinp', 'hashvz', 'beenben', 'appointedvbn', 'temporaryjj', 'assistantnn', 'districtnn', 'attorneynn', ',', ',', 'itpps', 'wasbedz', 'announcedvbn', 'Mondaynr', 'byin', 'Charlesnp', 'E.np', 'Raymondnp', ',', ',', 'Districtnn-tl', 'Attorneynn-tl', '..', 'Ierullinp', 'willmd', 'replacevb', 'Desmondnp', 'D.np', 'Connallnp', 'whowps', 'hashvz', 'beenben', 'calledvbn', 'toin', 'activejj', 'militaryjj', 'servicenn', 'butcc', 'isbez', 'expectedvbn', 'backrb', 'onin', 'theat', 'jobnn', 'byin', 'Marchnp', '31cd', '..', 'Ierullinp', ',', ',', '29cd', ',', ',', 'hashvz', 'beenben', 'practicingvbg', 'inin', 'Portlandnp', 'sincein', 'Novembernp', ',', ',', '1959cd', '..Hepps', 'isbez', 'aat', 'graduatenn', 'ofin', 'Portlandnp-tl', 'Universitynn-tl', 'andcc', 'theat', 'Northwesternjj-tl', 'Collegenn-tl', 'ofin-tl', 'Lawnn-tl', '..Hepps', 'isbez', 'marriedvbn', 'andcc', 'theat', 'fathernn', 'ofin', 'threecd', 'childrennns', '..', 'Helpingvbg', 'foreignjj', 'countriesnns',
# ...

# %% [markdown]
# Stop words
# ====
#
# **Stop words** are non-content words that primarily have only grammatical function
#
#
# Stopwords considered as noise in the text. Text may contain stop words such as is, am, are, this, a, an, the, etc.
#
#
# In NLTK for removing stopwords, you need to create a list of stopwords and filter out your list of tokens from these words.
#
#
# In NLTK, you can access them as follows:

# %%
from nltk.corpus import stopwords

stopwords_en = stopwords.words('english')

# %%
# Treat the multiple sentences as one document (no need to sent_tokenize)
# Tokenize and lowercase
single_tokenized_lowered = list(map(str.lower, word_tokenize(data2)))
print(single_tokenized_lowered)
# Out:
# ['vincentnp', 'g.np', 'ierullinp', 'hashvz', 'beenben', 'appointedvbn', 'temporaryjj', 'assistantnn', 'districtnn', 'attorneynn', ',', ',', 'itpps', 'wasbedz', 'announcedvbn', 'mondaynr', 'byin', 'charlesnp', 'e.np', 'raymondnp', ',', ',', 'districtnn-tl', 'attorneynn-tl', '..', 'ierullinp', 'willmd', 'replacevb', 'desmondnp', 'd.np', 'connallnp', 'whowps', 'hashvz', 'beenben', 'calledvbn', 'toin', 'activejj', 'militaryjj', 'servicenn', 'butcc', 'isbez', 'expectedvbn', 'backrb', 'onin', 'theat', 'jobnn', 'byin', 'marchnp', '31cd', '..', 'ierullinp', ',', ',', '29cd', ',', ',', 'hashvz', 'beenben', 'practicingvbg', 'inin', 'portlandnp', 'sincein', 'novembernp', ',', ',', '1959cd', '..hepps', 'isbez', 'aat', 'graduatenn', 'ofin', 'portlandnp-tl', 'universitynn-tl', 'andcc', 'theat', 'northwesternjj-tl', 'collegenn-tl', 'ofin-tl', 'lawnn-tl', '..hepps', 'isbez', 'marriedvbn', 'andcc', 'theat', 'fathernn', 'ofin', 'threecd', 'childrennns', '..', 'helpingvbg', 'foreignjj', 'countriesnns',
# ...

# %% [markdown]
# # Let's try to remove the stopwords using the English stopwords list in NLTK

# %%
stopwords_en = set(stopwords.words('english')) # Set checking is faster in Python than list.

# List comprehension.
print([word for word in single_tokenized_lowered if word not in stopwords_en])
# Out:
# ['vincentnp', 'g.np', 'ierullinp', 'hashvz', 'beenben', 'appointedvbn', 'temporaryjj', 'assistantnn', 'districtnn', 'attorneynn', ',', ',', 'itpps', 'wasbedz', 'announcedvbn', 'mondaynr', 'byin', 'charlesnp', 'e.np', 'raymondnp', ',', ',', 'districtnn-tl', 'attorneynn-tl', '..', 'ierullinp', 'willmd', 'replacevb', 'desmondnp', 'd.np', 'connallnp', 'whowps', 'hashvz', 'beenben', 'calledvbn', 'toin', 'activejj', 'militaryjj', 'servicenn', 'butcc', 'isbez', 'expectedvbn', 'backrb', 'onin', 'theat', 'jobnn', 'byin', 'marchnp', '31cd', '..', 'ierullinp', ',', ',', '29cd', ',', ',', 'hashvz', 'beenben', 'practicingvbg', 'inin', 'portlandnp', 'sincein', 'novembernp', ',', ',', '1959cd', '..hepps', 'isbez', 'aat', 'graduatenn', 'ofin', 'portlandnp-tl', 'universitynn-tl', 'andcc', 'theat', 'northwesternjj-tl', 'collegenn-tl', 'ofin-tl', 'lawnn-tl', '..hepps', 'isbez', 'marriedvbn', 'andcc', 'theat', 'fathernn', 'ofin', 'threecd', 'childrennns', '..', 'helpingvbg', 'foreignjj', 'countriesnns',
# ...

# %% [markdown]
# # Often, you want to remove the punctuations from the documents too.
#
# Since Python comes with "batteries included", you have string.punctuation

# %%
from string import punctuation
# It's a string so you have to them into a set type
print('From string.punctuation:', type(punctuation), punctuation)
# Out:
# From string.punctuation: <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# # Combining the punctuation with the stop words from NLTK.

# %%
stopwords_en_withpunct = stopwords_en.union(set(punctuation))
print(stopwords_en_withpunct)
# Out:
# {'nor', 'now', '?', 'that', '|', 'with', 'through', 'just', 'out', 'having', 'at', 'all', 'once', 're', 'off', 'those', 'against', 'wouldn', '>', 'can', 'the', 'their', 'again', 'because', 'few', 'if', 'after', ')', 'y', "it's", 'we', 'itself', 'they', 'm', 'd', 'over', 'about', '<', 'theirs', '-', 'only', 'why', 'any', "doesn't", "haven't", 'an', 'needn', 'couldn', 'when', 'who', 'each', 'shouldn', '{', 'be', 'our', 'aren', '.', 'mightn', "hasn't", 'how', 'yourselves', 'above', "should've", 'more', 'its', 'will', '*', ':', "couldn't", 'while', 'hadn', 'them', "shan't", 'do', 'me', 'he', 'this', 'into', 'is', 'hasn', 'weren', 'his', 'did', "you'd", 'won', '!', 'yours', "don't", 'doing', 'between', 'ain', 'until', '"', 'same', '@', 'here', "isn't", 'not', 'should', 'it', 'you', 'yourself', 'on', 'are', 'these', 'don', 'were', '`', 'been', '[', 'ma', '}', 'o', "wasn't", 'then', 'there', 'such', 'didn', 'some', 't', 'have', 'll', "mightn't", 'during', 'from', '#', 'to', "mustn't", 'myse
# ...

# %% [markdown]
# # Removing stop words with punctuations

# %%
print([word for word in single_tokenized_lowered if word not in stopwords_en_withpunct])
# Out:
# ['vincentnp', 'g.np', 'ierullinp', 'hashvz', 'beenben', 'appointedvbn', 'temporaryjj', 'assistantnn', 'districtnn', 'attorneynn', 'itpps', 'wasbedz', 'announcedvbn', 'mondaynr', 'byin', 'charlesnp', 'e.np', 'raymondnp', 'districtnn-tl', 'attorneynn-tl', '..', 'ierullinp', 'willmd', 'replacevb', 'desmondnp', 'd.np', 'connallnp', 'whowps', 'hashvz', 'beenben', 'calledvbn', 'toin', 'activejj', 'militaryjj', 'servicenn', 'butcc', 'isbez', 'expectedvbn', 'backrb', 'onin', 'theat', 'jobnn', 'byin', 'marchnp', '31cd', '..', 'ierullinp', '29cd', 'hashvz', 'beenben', 'practicingvbg', 'inin', 'portlandnp', 'sincein', 'novembernp', '1959cd', '..hepps', 'isbez', 'aat', 'graduatenn', 'ofin', 'portlandnp-tl', 'universitynn-tl', 'andcc', 'theat', 'northwesternjj-tl', 'collegenn-tl', 'ofin-tl', 'lawnn-tl', '..hepps', 'isbez', 'marriedvbn', 'andcc', 'theat', 'fathernn', 'ofin', 'threecd', 'childrennns', '..', 'helpingvbg', 'foreignjj', 'countriesnns', 'toto', 'buildvb', 'aat', 'soundjj', 'politicaljj
# ...

# %% [markdown]
# # Lexicon Normalization
#
# Lexicon normalization considers another type of noise in the text.
#
# For example, connection, connected, connecting word reduce to a common word "connect".
#
# It reduces derivationally related forms of a word to a common root word.
#
#
# ## Stemming
#
# Stemming is a process of linguistic normalization, which reduces words to their word root word or chops off the derivational affixes.
#
#
# For example, connection, connected, connecting word reduce to a common word "connect".
#
# ## Lemmatization
#
# Lemmatization reduces words to their base word, which is linguistically correct lemmas.
#
#
# It transforms root word with the use of vocabulary and morphological analysis.
#
#
# Lemmatization is usually more sophisticated than stemming.
#
#
# Stemmer works on an individual word without knowledge of the context.
#
#
# For example, The word "better" has "good" as its lemma.
#
#
# This thing will miss by stemming because it requires a dictionary look-up.
#
#
#
# The stemming and lemmatization process are hand-written regex rules written to find the root word.
#
#  - **Stemming**: Trying to shorten a word with simple regex rules. It's faster than Lemmatization.
#
#  - **Lemmatization**: Trying to find the root word with linguistics rules (with the use of regexes)

# %%
# %%time
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for word in single_tokenized_lowered :
    print(porter.stem(word))
# Out:
# vincentnp
# g.np
# ierullinp
# hashvz
# beenben
# appointedvbn
# temporaryjj
# assistantnn
# districtnn
# attorneynn
# ,
# ,
# itpp
# wasbedz
# announcedvbn
# mondaynr
# byin
# charlesnp
# e.np
# raymondnp
# ,
# ,
# districtnn-tl
# attorneynn-tl
# ..
# ierullinp
# willmd
# replacevb
# desmondnp
# d.np
# connallnp
# whowp
# hashvz
# beenben
# calledvbn
# toin
# activejj
# militaryjj
# servicenn
# butcc
# isbez
# expectedvbn
# backrb
# onin
# theat
# jobnn
# byin
# marchnp
# 31cd
# ..
# ierullinp
# ,
# ,
# 29cd
# ,
# ,
# hashvz
# beenben
# practicingvbg
# inin
# portlandnp
# sincein
# novembernp
# ,
# ,
# 1959cd
# ..hepp
# isbez
# aat
# graduatenn
# ofin
# portlandnp-tl
# universitynn-tl
# andcc
# theat
# northwesternjj-tl
# collegenn-tl
# ofin-tl
# lawnn-tl
# ..hepp
# isbez
# marriedvbn
# andcc
# theat
# fathernn
# ofin
# threecd
# childrennn
# ..
# helpingvbg
# foreignjj
# countriesnn
# toto
# buildvb
# aat
# soundjj
# politicaljj
# structurenn
# isbez
# moreql
# importantjj
# thanc
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\VIPUL.GAUR\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# %%time

from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

for word in single_tokenized_lowered:
    print(wnl.lemmatize(word))
# Out:
# vincentnp
# g.np
# ierullinp
# hashvz
# beenben
# appointedvbn
# temporaryjj
# assistantnn
# districtnn
# attorneynn
# ,
# ,
# itpps
# wasbedz
# announcedvbn
# mondaynr
# byin
# charlesnp
# e.np
# raymondnp
# ,
# ,
# districtnn-tl
# attorneynn-tl
# ..
# ierullinp
# willmd
# replacevb
# desmondnp
# d.np
# connallnp
# whowps
# hashvz
# beenben
# calledvbn
# toin
# activejj
# militaryjj
# servicenn
# butcc
# isbez
# expectedvbn
# backrb
# onin
# theat
# jobnn
# byin
# marchnp
# 31cd
# ..
# ierullinp
# ,
# ,
# 29cd
# ,
# ,
# hashvz
# beenben
# practicingvbg
# inin
# portlandnp
# sincein
# novembernp
# ,
# ,
# 1959cd
# ..hepps
# isbez
# aat
# graduatenn
# ofin
# portlandnp-tl
# universitynn-tl
# andcc
# theat
# northwesternjj-tl
# collegenn-tl
# ofin-tl
# lawnn-tl
# ..hepps
# isbez
# marriedvbn
# andcc
# theat
# fathernn
# ofin
# threecd
# childrennns
# ..
# helpingvbg
# foreignjj
# countriesnns
# toto
# buildvb
# aat
# soundjj
# politicaljj
# structurenn
# isbez
# moreql
# importantjj
# ...

# %% [markdown]
# # POS Tagging
#
# The primary target of Part-of-Speech(POS) tagging is to identify the grammatical group of a given word.
#
#
# Whether it is a NOUN, PRONOUN, ADJECTIVE, VERB, ADVERBS, etc. based on the context.
#
#
# POS Tagging looks for relationships within the sentence and assigns a corresponding tag to the word.

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\VIPUL.GAUR\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
stop_words = set(stopwords.words('english'))  
tokenized = sent_tokenize(data2) 
for i in tokenized: 
    wordsList = nltk.word_tokenize(i) 
    #wordsList = [w for w in wordsList if not w in stop_words]  stopwords_en_withpunct
    wordsList = [w for w in wordsList if not w in stopwords_en_withpunct]  
    tagged = nltk.pos_tag(wordsList) 
  
print(tagged)
# Out:
# [('.weppss', 'JJ'), ('needvb', 'RB'), ('100cd', 'CD'), ('inin', 'JJ'), ('Rhodenp-tl', 'JJ'), ('Islandnn-tl', 'NNP'), ('weppss', 'NN'), ('havehv', 'NN'), ('nonepn', 'IN'), ('``', '``'), ("''", "''"), ('hepps', 'NN'), ('saidvbd', 'VBD'), ('..', 'NNP'), ('Toto', 'NNP'), ('stepvb', 'VBD'), ('uprp', 'JJ'), ('theat', 'NN'), ("denomination'snn", 'NN'), ('programnn', 'NN'), ('theat', 'NN'), ('Rev.np', 'NNP'), ('Mr.np', 'NNP'), ('Brandtnp', 'NNP'), ('suggestedvbd', 'VBD'), ('theat', 'NN'), ('visionnn', 'NN'), ('ofin', 'VBD'), ('8,000cd', 'CD'), ('newjj', 'JJ'), ('Assembliesnns-tl', 'JJ'), ('ofin-tl', 'JJ'), ('Godnp-tl', 'NNP'), ('churchesnns', 'NN'), ('inin', 'NN'), ('theat', 'NN'), ('nextap', 'JJ'), ('10cd', 'CD'), ('yearsnns', 'NN'), ('..', 'NNP'), ('Toto', 'NNP'), ('accomplishvb', 'VBZ'), ('thisdt', 'JJ'), ('wouldmd', 'NN'), ('necessitatevb', 'NN'), ('somedti', 'NN'), ('changesnns', 'NN'), ('inin', 'NN'), ('methodsnns', 'NN'), ('hepps', 'NN'), ('saidvbd', 'NN'), ('..', 'NN'), ("''", "''"),
# ...

# %%
sent = "Albert Einstein was born in Ulm, Germany in 1879."

tokens=nltk.word_tokenize(sent)
print(tokens)
# Out:
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']

# %%
nltk.pos_tag(tokens)
# Out:
# [('Albert', 'NNP'),
#  ('Einstein', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Ulm', 'NNP'),
#  (',', ','),
#  ('Germany', 'NNP'),
#  ('in', 'IN'),
#  ('1879', 'CD'),
#  ('.', '.')]

# %% [markdown]
# ## POS tagged: Albert/NNP Einstein/NNP was/VBD born/VBN in/IN Ulm/NNP ,/, Germany/NNP in/IN 1879/CD ./.

# %% [markdown]
# # Chunking
#
# Chunking is used to add more structure to the sentence by following parts of speech (POS) tagging.
#
#
# It is also known as shallow parsing.
#
#
# The resulted group of words is called "chunks."
#
#
# In shallow parsing, there is maximum one level between roots and leaves while deep parsing comprises of more than one level.
#
#
# Shallow Parsing is also called light parsing or chunking.
#
#
# The primary usage of chunking is to make a group of "noun phrases."
#
#
# The parts of speech are combined with regular expressions.
#
#
# ## Rules for Chunking:
#
# There are no pre-defined rules, but you can combine them according to need and requirement.
#
#
# For example, you need to tag Noun, verb (past tense), adjective, and coordinating junction from the sentence. You can use the rule as below
#
#
# chunk:{<NN.?>*<VBD.?>*<JJ.?>*<CC>?}
#
#
# #### Let's define a rule and apply it on a sentence:

# %%
from nltk import pos_tag
from nltk import RegexpParser
text ="learning advanced machine learning course from simplilearn made it easy for everyone".split()
print("After Split:",text)
tokens_tag = pos_tag(text)
print("After Token:",tokens_tag)
patterns= """mychunk:{<NN.?>*<VBD.?>*<JJ.?>*<CC>?}"""
chunker = RegexpParser(patterns)
print("After Regex:",chunker)
output = chunker.parse(tokens_tag)
print("After Chunking",output)
# Out:
# After Split: ['learning', 'advanced', 'machine', 'learning', 'course', 'from', 'simplilearn', 'made', 'it', 'easy', 'for', 'everyone']
# After Token: [('learning', 'VBG'), ('advanced', 'JJ'), ('machine', 'NN'), ('learning', 'VBG'), ('course', 'NN'), ('from', 'IN'), ('simplilearn', 'NN'), ('made', 'VBD'), ('it', 'PRP'), ('easy', 'JJ'), ('for', 'IN'), ('everyone', 'NN')]
# After Regex: chunk.RegexpParser with 1 stages:
# RegexpChunkParser with 1 rules:
#        <ChunkRule: '<NN.?>*<VBD.?>*<JJ.?>*<CC>?'>
# After Chunking (S
#   learning/VBG
#   (mychunk advanced/JJ)
#   (mychunk machine/NN)
#   learning/VBG
#   (mychunk course/NN)
#   from/IN
#   (mychunk simplilearn/NN made/VBD)
#   it/PRP
#   (mychunk easy/JJ)
#   for/IN
#   (mychunk everyone/NN))

# %% [markdown]
# ### The conclusion from the above example: "makes" is a verb which is not included in the rule, so it is not tagged as mychunk
#
# # Use Case of Chunking
#
# Chunking is used for entity detection.
#
#
# An entity is that part of the sentence by which machine get the value for any intention
#
#
# Example:
#
# Temperature of New York.
#
#
# Here Temperature is the intention and New York is an entity.
#
#
# In other words, chunking is used as selecting the subsets of tokens.
#
#
# Please follow the below code to understand how chunking is used to select the tokens.
#
#
# In this example, you will see the graph which will correspond to a chunk of a noun phrase. We will write the code and draw the graph for better understanding.

# %%
import nltk
text = "learn advanced Machine Learning from Simplilearn"
tokens = nltk.word_tokenize(text)
print(tokens)
tag = nltk.pos_tag(tokens)
print(tag)
grammar = "NP: {<DT>?<JJ>*<NN>}"
cp  =nltk.RegexpParser(grammar)
result = cp.parse(tag)
print(result)
#result.draw()    # It will draw the pattern graphically which can be seen in Noun Phrase chunking
# Out:
# ['learn', 'advanced', 'Machine', 'Learning', 'from', 'Simplilearn']
# [('learn', 'NN'), ('advanced', 'VBD'), ('Machine', 'NNP'), ('Learning', 'VBG'), ('from', 'IN'), ('Simplilearn', 'NNP')]
# (S
#   (NP learn/NN)
#   advanced/VBD
#   Machine/NNP
#   Learning/VBG
#   from/IN
#   Simplilearn/NNP)

# %% [markdown]
# #### From above, we can conclude that "learn" and "simplilearn" are two different tokens but are categorized as Noun Phrase whereas token "from" does not belong to Noun Phrase.
#
# Chunking is used to categorize different tokens into the same chunk.
#
#
# The result will depend on grammar which has been selected.
#
#
# Further chunking is used to tag patterns and to explore text corpora.

# %% [markdown]
# # Extracting Entity Names

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\VIPUL.GAUR\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\VIPUL.GAUR\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
sentences = nltk.sent_tokenize(data2)
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)

def extract_entity_names(t):
    entity_names = []

    if hasattr(t, 'label') and t.label:
        if t.label() == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))

    return entity_names

entity_names = []
for tree in chunked_sentences:
    entity_names.extend(extract_entity_names(tree))

# Print unique entity names
print (set(entity_names))
# Out:
# {'Jacknp', 'Martinnp', 'Oregonnp', 'Donaldnp Huffmannp', 'Salemnp', 'Jamesnp', 'Ajnn', 'Tuesdaynr', 'Portlandnp', 'SWnn Maplecrestnp', 'Sovietnp', 'Barbaranp Njustnp', 'Dwightnp', 'Deannp Brysonnp', 'Blainenp Whipplenp', 'Alnp Ullmannp', 'Eugenenp', 'Americansnps', 'Jamesnp Culbertsonnp', 'Milesnp', 'Losnp Angelesnp', 'Vincentnp', 'Attorneynn Dwightnp', 'Philipnp Weinsteinnp', 'Franknp Leenp', 'Biblenp', 'Hepps'}

# %% [markdown]
# # Chinking
#
# You may find that, after a lot of chunking, you have some words in your chunk you still do not want, but you have no idea how to get rid of them by chunking. You may find that chinking is your solution.
#
# #### Chinking is a lot like chunking, it is basically a way for you to remove a chunk from a chunk.
#
# The chunk that you remove from your chunk is your chink.
#
#
# The code is very similar, you just denote the chink, after the chunk, with ***} {*** instead of the chunk's ***{ }***.

# %%
nltk.download('state_union')
# Out:
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\VIPUL.GAUR\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# True

# %% [markdown]
# # Run from Terminal
#
# import nltk
# from nltk.corpus import state_union
# from nltk.tokenize import PunktSentenceTokenizer
#
# train_text = state_union.raw("2005-GWBush.txt")
# sample_text = state_union.raw("2006-GWBush.txt")
#
# custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
#
# tokenized = custom_sent_tokenizer.tokenize(sample_text)
#
# def process_content():
#     try:
#         for i in tokenized[5:]:
#             words = nltk.word_tokenize(i)
#             tagged = nltk.pos_tag(words)
#
#             chunkGram = r"""Chunk: {<.*>+}
#                                     }<VB.?|IN|DT|TO>+{"""
#
#             chunkParser = nltk.RegexpParser(chunkGram)
#             chunked = chunkParser.parse(tagged)
#
#             chunked.draw()
#
#     except Exception as e:
#         print(str(e))
#
# process_content()

# %% [markdown]
# Now, the main difference here is:
#
# }<VB.?|IN|DT|TO>+{
# This means we're removing from the chink one or more verbs, prepositions, determiners, or the word 'to'.
#
# Now that we've learned how to do some custom forms of chunking, and chinking, let's discuss a built-in form of chunking that comes with NLTK, and that is named entity recognition.
