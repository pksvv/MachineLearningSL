# %%
# !pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/d6/9e/6a42486ffa64711fb868e5d4a9167153417e7414c3d8d3e0d627cf391e1e/scikit_learn-0.21.3-cp37-cp37m-win_amd64.whl (5.9MB)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\vipul.gaur\anaconda3\lib\site-packages (from scikit-learn) (0.13.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\vipul.gaur\anaconda3\lib\site-packages (from scikit-learn) (1.2.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\vipul.gaur\anaconda3\lib\site-packages (from scikit-learn) (1.16.2)
# Installing collected packages: scikit-learn
#   Found existing installation: scikit-learn 0.21.1
#     Uninstalling scikit-learn-0.21.1:
#       Successfully uninstalled scikit-learn-0.21.1
# Successfully installed scikit-learn-0.21.3

# %%
import sklearn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %%
print(sklearn.__version__)
# Out:
# 0.21.3

# %%
print(np.__version__)
# Out:
# 1.16.2

# %%
print(pd.__version__)
# Out:
# 0.24.2

# %%
automobile_df = pd.read_csv('datasets/auto-mpg.csv')

automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 160  17.0          6         231.0        110    3907          21.0
# 131  32.0          4          71.0         65    1836          21.0
# 26   10.0          8         307.0        200    4376          15.0
# 317  34.3          4          97.0         78    2188          15.8
# 290  15.5          8         351.0        142    4054          14.3
#
#      model year  origin                  car name
# 160          75       1             buick century
# 131          74       3       toyota corolla 1200
# 26           70       1                 chevy c20
# 317          80       2                 audi 4000
# 290          79       1  ford country squire (sw)

# %%
automobile_df.shape
# Out:
# (398, 9)

# %%
automobile_df = automobile_df.replace('?', np.nan)

# %%
automobile_df = automobile_df.dropna()

# %%
automobile_df.shape
# Out:
# (392, 9)

# %% [markdown]
# #### Drop columns which don't make sense as features

# %%
automobile_df.drop(['origin', 'car name'], axis=1, inplace=True)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 291  19.2          8         267.0        125    3605          15.0
# 117  29.0          4          68.0         49    1867          19.5
# 76   18.0          4         121.0        112    2933          14.5
# 107  18.0          6         232.0        100    2789          15.0
# 15   22.0          6         198.0         95    2833          15.5
#
#      model year
# 291          79
# 117          73
# 76           72
# 107          73
# 15           70

# %% [markdown]
# #### Convert to a complete year format

# %%
automobile_df['model year'] = '19' + automobile_df['model year'].astype(str)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration model year
# 195  29.0          4          85.0         52    2035          22.2       1976
# 105  13.0          8         360.0        170    4654          13.0       1973
# 84   27.0          4          97.0         88    2100          16.5       1972
# 186  27.0          4         101.0         83    2202          15.3       1976
# 194  22.5          6         232.0         90    3085          17.6       1976

# %% [markdown]
# #### Add an age column

# %%
automobile_df['age'] = datetime.datetime.now().year - pd.to_numeric(automobile_df['model year'])

# %%
automobile_df.drop(['model year'], axis=1, inplace=True)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  age
# 196  24.5          4          98.0         60    2164          22.1   43
# 357  32.9          4         119.0        100    2615          14.8   38
# 234  24.5          4         151.0         88    2740          16.0   42
# 228  18.5          6         250.0         98    3525          19.0   42
# 231  15.5          8         400.0        190    4325          12.2   42

# %%
automobile_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# age               int64
# dtype: object

# %%
automobile_df['horsepower'] = pd.to_numeric(automobile_df['horsepower'], errors='coerce')

# %%
automobile_df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration         age
# count    392.000000  392.000000
# mean      15.541327   43.020408
# std        2.758864    3.683737
# min        8.000000   37.000000
# 25%       13.775000   40.000000
# 50%       15.500000   43.000000
# 75%       17.025000   46.000000
# max       24.800000   49.000000

# %% [markdown]
# ### Visualizing relationships

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(automobile_df['age'], automobile_df['mpg'])

plt.xlabel('Age')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(automobile_df['acceleration'], automobile_df['mpg'])

plt.xlabel('Acceleration')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(automobile_df['weight'], automobile_df['mpg'])

plt.xlabel('Weight')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(automobile_df['displacement'], automobile_df['mpg'])

plt.xlabel('Displacement')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(automobile_df['horsepower'], automobile_df['mpg'])

plt.xlabel('Horsepower')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(automobile_df['cylinders'], automobile_df['mpg'])

plt.xlabel('Cylinders')
plt.ylabel('Miles per gallon')
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
automobile_corr = automobile_df.corr()

automobile_corr
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# age          -0.580541   0.345647      0.369855    0.416361  0.309120
#
#               acceleration       age
# mpg               0.423329 -0.580541
# cylinders        -0.504683  0.345647
# displacement     -0.543800  0.369855
# horsepower       -0.689196  0.416361
# weight           -0.416839  0.309120
# acceleration      1.000000 -0.290316
# age              -0.290316  1.000000

# %%
fig, ax = plt.subplots(figsize=(12, 10))

sns.heatmap(automobile_corr, annot=True)

# %%
automobile_df = automobile_df.sample(frac=1).reset_index(drop=True)

automobile_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 0  32.7          6         168.0         132    2910          11.4   39
# 1  28.0          4         140.0          90    2264          15.5   48
# 2  22.0          6         198.0          95    2833          15.5   49
# 3  17.0          6         250.0         100    3329          15.5   48
# 4  16.5          8         351.0         138    3955          13.2   40

# %%
automobile_df.to_csv('datasets/auto-mpg-processed.csv', index=False)

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CC93-C27E
#
#  Directory of C:\Users\VIPUL.GAUR\Documents\Day 3 - 17-Aug-2019\regression-sklearn
#
# 08/16/2019  03:40 PM    <DIR>          .
# 08/16/2019  03:40 PM    <DIR>          ..
# 08/16/2019  03:36 PM    <DIR>          .ipynb_checkpoints
# 08/16/2019  03:40 PM           227,852 01-ExploringTheAutomobileMpgDataset.ipynb
# 02/24/2019  01:05 AM           197,301 02-SimpleRegression_NumericValues_AutomobileMpg.ipynb
# 02/24/2019  01:05 AM           107,660 03-SimpleRegression_CategoricalValues_ExamScores.ipynb
# 02/24/2019  12:29 PM         1,489,031 04-MultipleRegressionModels_AutomobileMpg.ipynb
# 02/24/2019  01:05 AM            14,546 05-HyperparameterTuningWithGridSearch.ipynb
# 08/16/2019  03:32 PM    <DIR>          datasets
#                5 File(s)      2,036,390 bytes
#                4 Dir(s)  256,760,496,128 bytes free

# %%
# !cd datasets && dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CC93-C27E
#
#  Directory of C:\Users\VIPUL.GAUR\Documents\Day 3 - 17-Aug-2019\regression-sklearn\datasets
#
# 08/16/2019  03:32 PM    <DIR>          .
# 08/16/2019  03:32 PM    <DIR>          ..
# 08/16/2019  03:40 PM            11,888 auto-mpg-processed.csv
# 02/24/2019  01:05 AM            18,131 auto-mpg.csv
# 02/24/2019  01:05 AM             7,304 exams.csv
#                3 File(s)         37,323 bytes
#                2 Dir(s)  256,760,430,592 bytes free
